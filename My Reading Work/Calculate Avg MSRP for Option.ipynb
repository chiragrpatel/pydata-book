# %% [markdown]
# First get all required data for our analysis.
# Try to restrict data from source, so that we don't have to deal with lot of unnecessary data

# %%
import cx_Oracle
import pandas as pd

con = cx_Oracle.connect('VCI_DATA_ANALYTICS','VCI_DATA_ANALYTICSpre',cx_Oracle.makedsn('ddmprod.usvci001.vci.na.vwg',1527,'DIM_PREPROD'))
sqlToGetVehicleData = """select vid.* from dw_mart.BRAND_VEHICLE_INVOICE_DTL vid
inner join dw_mart.vehicle_dim vd on vd.VEHICLE_ID_NBR = vid.VEHICLE_ID_NBR and vd.CLOSE_DT_ID= 99991231
where vd.MAKE_NM = 'Audi' and vd.MODEL_YEAR_NBR = '2018' 
and vd.MODEL_NBR = '4S95AE'"""
vehicle_invoice_data = pd.read_sql(sqlToGetVehicleData, con)

# %%
vehicle_invoice_data
# Out:
#      BRAND_VEHICLE_INVOICE_ID  BATCH_CONTROL_DT_ID     VEHICLE_ID_NBR  \
# 0                    27329669             20181220  WUAVACFX1J7900524
# 1                    27327944             20181220  WUAVACFX1J7900068
# 2                    27334625             20181220  WUAVACFX1J7900586
# 3                    27318647             20181220  WUAVACFX6J7900082
# 4                    27323879             20181220  WUAVACFX9J7900075
# 5                    27323224             20181220  WUAVACFX3J7900203
# 6                    27318986             20181220  WUAVACFX1J7900989
# 7                    27311856             20181220  WUAVACFX2J7900368
# 8                    27311720             20181220  WUAVACFX7J7901032
# 9                    27311869             20181220  WUAVACFX4J7900064
# 10                   27311891             20181220  WUAVACFX1J7900166
# 11                   27401352             20181220  WUAVACFX7J7900592
# 12                   27452529             20181220  WUAVACFX2J7900872
# 13                   27793610             20181220  WUAVACFX5J7902454
# 14                  558220161             20190312  WUAVACFX1J7900149
# 15                   27329335             20181220  WUAVACFX8J7900049
# 16                   27329053             20181220  WUAVACFX0J7900479
# 17                   27350563             20181220  WUAVACFXXJ7900148
# 18                   27350557             20181220  WUAVACFX7J7900091
# 19                   27320123             20181220  WUAVACFX4J7900274
# 20                   27323921             20181220  WUAVACFX9J7900366
# 21                   27323851             20181220  WUAVACFX6J7900177
# 22                   27311752             20181220  WUAVACFX8J7900293
# 23                   27312639             20181220  WUAVACFX1J7900944
# 24                   27368976             20181220  WUAVACFX7J7900091
# 25                   27368848             20181220  WUAVACFX7J7900091
# 26                   27364793             20181220  WUAVACFX7J7900091
# 27                   27364920             20181220  WUAVACFX7J7900091
# 28                   27501120             20181220  WUAVACFX0J7901826
# 29                   27499920             20181220  WUAVACFX1J7901981
# ..                        ...                  ...                ...
# 237                  27590848             20181220  WUAVACFX2J7902198
# 238                  27575942             20181220  WUAVACFX2J7901813
# 239                  27729582             20181220  WUAVACFX4J7902350
# 240                 558226344             20190312  WUAVACFX2J7900046
# 241                 558226658             20190312  WUAVACFX2J7900046
# 242                 558216347             20190312  WUAVACFX4J7900968
# 243                 558215852             20190312  WUAVACFX4J7900968
# 244                  27329371             20181220  WUAVACFX4J7900081
# 238  7407853175  08/08/2018       7407853175      USD                062018
# 239  7407989040  10/23/2018       7407989040      USD                092018
# 240  7301148511  04/27/2018       7301148511      CAD                082017
# 241  7301148511  04/27/2018       7301148511      CAD                082017
# 242  7301137177  03/28/2018       7301137177      CAD                012018
# 243  7301137177  03/28/2018       7301137177      CAD                012018
# 244  7407630029  04/09/2018       7407630029      USD                082017
# 245  7407630058  04/09/2018       7407630058      USD                092017
# 246  7407629961  04/09/2018       7407629961      USD                082017
# 247  7407626413  04/06/2018       7407626413      USD                082017
# 248  7407626391  04/06/2018       7407626391      USD                082017
# 249  7407612885  03/28/2018       7407612885      USD                082017
# 250  7407641973  04/17/2018       7407641973      USD                112017
# 251  7407637059  04/12/2018       7407637059      USD                082017
# 252  7407694185  05/18/2018       7407694185      USD                092017
# 253  7408049406  11/23/2018       7408049406      USD                102018
# 254  7301151728  05/07/2018       7301151728      CAD                082017
# 255  7301151728  05/07/2018       7301151728      CAD                082017
# 256  7301137178  03/28/2018       7301137178      CAD                082017
# 257  7301137178  03/28/2018       7301137178      CAD                082017
# 258  7301141193  04/09/2018       7301141193      CAD                082017
# 259  7301152761  05/09/2018       7301152761      CAD                082017
# 260  7301151176  05/04/2018       7301151176      CAD                082017
# 261  7301151176  05/04/2018       7301151176      CAD                082017
# 262  7301152761  05/09/2018       7301152761      CAD                082017
# 263  7301141648  04/10/2018       7301141648      CAD                102017
# 264  7301144557  04/17/2018       7301144557      CAD                082017
# 265  7301144557  04/17/2018       7301144557      CAD                082017
# 266  7301141648  04/10/2018       7301141648      CAD                102017
#
#      ENGINE_NBR MODEL_NBR         ...         EXTRA_COST_DLR_I10_AMT  \
# 0    DKA 001525    4S95AE         ...                           0.00
# 1    DKA 001041    4S95AE         ...                           0.00
# 2    DKA 001584    4S95AE         ...                           0.00
# 3    DKA 001072    4S95AE         ...                           0.00
# 4    DKA 001065    4S95AE         ...                           0.00
# 5    DKA 001221    4S95AE         ...                           0.00
# 6    DKA 001996    4S95AE         ...                           0.00
# 7    DKA 001317    4S95AE         ...                           0.00
# 8    DKA 002019    4S95AE         ...                           0.00
# 9    DKA 001050    4S95AE         ...                           0.00
# 10   DKA 001167    4S95AE         ...                           0.00
# 11   DKA 001554    4S95AE         ...                           0.00
# 12   DKA 001883    4S95AE         ...                           0.00
# 13   DKA 003471    4S95AE         ...                           0.00
# 14   DKA 001148    4S95AE         ...                        9943.70
# 15   DKA 001032    4S95AE         ...                           0.00
# 16   DKA 001479    4S95AE         ...                           0.00
# 17   DKA 001150    4S95AE         ...                           0.00
# 18   DKA 001087    4S95AE         ...                           0.00
# 19   DKA 001282    4S95AE         ...                           0.00
# 20   DKA 001332    4S95AE         ...                           0.00
# 21   DKA 001181    4S95AE         ...                           0.00
# 22   DKA 001242    4S95AE         ...                           0.00
# 23   DKA 001946    4S95AE         ...                           0.00
# 24   DKA 001087    4S95AE         ...                           0.00
# 25   DKA 001087    4S95AE         ...                           0.00
# 26   DKA 001087    4S95AE         ...                           0.00
# 27   DKA 001087    4S95AE         ...                           0.00
# 28   DKA 002851    4S95AE         ...                           0.00
# 29   DKA 002971    4S95AE         ...                           0.00
# ..          ...       ...         ...                            ...
# 237  DKA 003232    4S95AE         ...                           0.00
# 238  DKA 002833    4S95AE         ...                           0.00
# 239  DKA 003350    4S95AE         ...                           0.00
# 240  DKA 001048    4S95AE         ...                       10208.85
# 241  DKA 001048    4S95AE         ...                       10208.85
# 242  DKA 001984    4S95AE         ...                       10494.90
# 243  DKA 001984    4S95AE         ...                       10494.90
# 244  DKA 001067    4S95AE         ...                           0.00
# 245  DKA 001260    4S95AE         ...                           0.00
# 246  DKA 001218    4S95AE         ...                           0.00
# 247  DKA 001046    4S95AE         ...                           0.00
# 248  DKA 001089    4S95AE         ...                           0.00
# 249  DKA 001076    4S95AE         ...                           0.00
# 250  DKA 001364    4S95AE         ...                           0.00
# 251  DKA 001208    4S95AE         ...                           0.00
# 252  DKA 001270    4S95AE         ...                           0.00
# 253  DKA 003554    4S95AE         ...                           0.00
# 254  DKA 001115    4S95AE         ...                       26581.13
# 255  DKA 001115    4S95AE         ...                       26581.13
# 256  DKA 001141    4S95AE         ...                       10032.10
# 257  DKA 001141    4S95AE         ...                       10032.10
# 258  DKA 001148    4S95AE         ...                        9943.70
# 259  DKA 001134    4S95AE         ...                       27125.18
# 260  DKA 001107    4S95AE         ...                       10392.55
# 261  DKA 001107    4S95AE         ...                       10392.55
# 262  DKA 001134    4S95AE         ...                       27125.18
# 263  DKA 001473    4S95AE         ...                       26296.82
# 264  DKA 001182    4S95AE         ...                       10280.95
# 265  DKA 001182    4S95AE         ...                       10280.95
# 266  DKA 001473    4S95AE         ...                       26296.82
#
#      EXTRA_COST_RTL_I10_AMT  TOTAL_DLR_PRICE_AMT RTL_PRICE_TOT_AMT COUNTRY_NM  \
# 0                      0.00            194895.88         207925.00    USxxxxx
# 1                      0.00            196153.60         209270.00    USxxxxx
# 2                      0.00            184972.03         195550.00    USxxxxx
# 3                      0.00            186645.98         197340.00    USxxxxx
# 4                      0.00            187041.88         199525.00    USxxxxx
# 5                      0.00            187551.60         200070.00    USxxxxx
# 6                      0.00            174793.38         186425.00    USxxxxx
# 7                      0.00            174325.88         185925.00    USxxxxx
# 8                      0.00            177972.38         189825.00    USxxxxx
# 9                      0.00            187551.60         200070.00    USxxxxx
# 10                     0.00            185307.60         197670.00    USxxxxx
# 11                     0.00            188362.03         199695.00    USxxxxx
# 12                     0.00            183023.00         195725.00    USxxxxx
# 13                     0.00            189757.03         201195.00    USxxxxx
# 14                 10649.25            208817.70         223634.25    CAxxxxx
# 15                     0.00            179393.98         191345.00    USxxxxx
# 16                     0.00            178813.88         190725.00    USxxxxx
# 17                     0.00            185338.00         198215.00    USxxxxx
# 18                     0.00            184873.00         197715.00    USxxxxx
# 19                     0.00            186444.91         197125.00    USxxxxx
# 20                     0.00            184279.10         196570.00    USxxxxx
# 21                     0.00            179871.76         190095.00    USxxxxx
# 22                     0.00            186444.91         197125.00    USxxxxx
# 23                     0.00            186597.50         199050.00    USxxxxx
# 24                     0.00           -184873.00        -197715.00    USxxxxx
# 25                     0.00            184873.00         197715.00    USxxxxx
# 26                     0.00            184873.00         197715.00    USxxxxx
# 27                     0.00           -184873.00        -197715.00    USxxxxx
# 28                     0.00            181535.00         194125.00    USxxxxx
# 29                     0.00            184325.00         197125.00    USxxxxx
# ..                      ...                  ...               ...        ...
# 237                    0.00            183825.00         197125.00    USxxxxx
# 238                    0.00            172979.00         184925.00    USxxxxx
# 239                    0.00            175769.00         187925.00    USxxxxx
# 240                10934.25            214385.85         229619.25    CAxxxxx
# 241                10934.25            214385.85         229619.25    CAxxxxx
# 242                11241.75            220392.90         236076.75    CAxxxxx
# 243                11241.75            220392.90         236076.75    CAxxxxx
# 244                    0.00            186616.60         199070.00    USxxxxx
# 245                    0.00            184866.00         198245.00    USxxxxx
# 246                    0.00            182614.20         194790.00    USxxxxx
# 247                    0.00            182970.10         195170.00    USxxxxx
# 248                    0.00            187089.13         199575.00    USxxxxx
# 249                    0.00            189613.63         202275.00    USxxxxx
# 250                    0.00            187976.88         200525.00    USxxxxx
# 251                    0.00            186564.00         200070.00    USxxxxx
# 252                    0.00            181070.00         193625.00    USxxxxx
# 253                    0.00            172049.00         183925.00    USxxxxx
# 254                28515.27            231051.33         247863.47    CAxxxxx
# 255                28515.27            231051.33         247863.47    CAxxxxx
# 256                10744.25            210674.10         225629.25    CAxxxxx
# 257                10744.25            210674.10         225629.25    CAxxxxx
# 258                10649.25            208817.70         223634.25    CAxxxxx
# 259                29054.77            235780.38         252552.97    CAxxxxx
# 260                11149.25            218243.55         234134.25    CAxxxxx
# 261                11149.25            218243.55         234134.25    CAxxxxx
# 262                29054.77            235780.38         252552.97    CAxxxxx
# 263                28164.27            228580.02         244812.47    CAxxxxx
# 264                11011.75            215899.95         231246.75    CAxxxxx
# 265                11011.75            215899.95         231246.75    CAxxxxx
# 266                28164.27            228580.02         244812.47    CAxxxxx
#
#                SRC_FILE_NM                                      CREATE_BY_NM  \
# 0    vwauus_20180411040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 1    vwauus_20180411040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 2    vwauus_20180413040011  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 3    vwauus_20180405040006  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 4    vwauus_20180408040011  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 5    vwauus_20180407040002  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 6    vwauus_20180406040001  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 7    vwauus_20180330040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 8    vwauus_20180330040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 9    vwauus_20180330040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 10   vwauus_20180330040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 11   vwauus_20180520040001  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 12   vwauus_20180620040002  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 13   vwauus_20181117040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 14   auauca_20180411050113  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 15   vwauus_20180411040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 16   vwauus_20180411040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 17   vwauus_20180422040001  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 18   vwauus_20180422040001  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 19   vwauus_20180406040001  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 20   vwauus_20180408040011  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 21   vwauus_20180408040011  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 22   vwauus_20180330040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 23   vwauus_20180331040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 24   vwauus_20180505040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
# 25   vwauus_20180505040004  S_TFS71777_FF_DIM_BRAND_VEHICLE_INVOICE_BACKFILL
#
# 240 2019-03-13 09:57:02
# 241 2019-03-13 09:57:02
# 242 2019-03-13 09:57:02
# 243 2019-03-13 09:57:02
# 244 2018-12-21 12:05:12
# 245 2018-12-21 12:05:12
# 246 2018-12-21 12:05:12
# 247 2018-12-21 12:05:12
# 248 2018-12-21 12:05:12
# 249 2018-12-21 12:05:12
# 250 2018-12-21 12:05:12
# 251 2018-12-21 12:05:12
# 252 2018-12-21 12:05:12
# 253 2018-12-21 12:05:12
# 254 2019-03-13 09:57:02
# 255 2019-03-13 09:57:02
# 256 2019-03-13 09:57:02
# 257 2019-03-13 09:57:02
# 258 2019-03-13 09:57:02
# 259 2019-03-13 09:57:02
# 260 2019-03-13 09:57:02
# 261 2019-03-13 09:57:02
# 262 2019-03-13 09:57:02
# 263 2019-03-13 09:57:02
# 264 2019-03-13 09:57:02
# 265 2019-03-13 09:57:02
# 266 2019-03-13 09:57:02
#
# [267 rows x 149 columns]

# %%
vehicle_invoice_data.columns
# Out:
# Index(['BRAND_VEHICLE_INVOICE_ID', 'BATCH_CONTROL_DT_ID', 'VEHICLE_ID_NBR',
#        'INVOICE_NBR', 'INVOICE_DT', 'REF_INVOICE_NBR', 'CURRENCY',
#        'PRODUCTION_MONTH_YEAR', 'ENGINE_NBR', 'MODEL_NBR',
#        ...
#        'EXTRA_COST_DLR_I10_AMT', 'EXTRA_COST_RTL_I10_AMT',
#        'TOTAL_DLR_PRICE_AMT', 'RTL_PRICE_TOT_AMT', 'COUNTRY_NM', 'SRC_FILE_NM',
#        'CREATE_BY_NM', 'CREATE_DT', 'MOD_BY_NM', 'MOD_DT'],
#       dtype='object', length=149)

# %%
vehicle_invoice_data_md = vehicle_invoice_data.columns

# %%
for column_nm in vehicle_invoice_data_md: 
    print(column_nm)
# Out:
# BRAND_VEHICLE_INVOICE_ID
# BATCH_CONTROL_DT_ID
# VEHICLE_ID_NBR
# INVOICE_NBR
# INVOICE_DT
# REF_INVOICE_NBR
# CURRENCY
# PRODUCTION_MONTH_YEAR
# ENGINE_NBR
# MODEL_NBR
# MODEL_DESC
# MODEL_DEALER_PRICE_AMT
# MODEL_RTL_PRICE_AMT
# EXT_COLOR_CD
# EXT_COLOR_CD_DESC
# EXT_COLOR_DLR_PRICE_AMT
# EXT_COLOR_RTL_PRICE_AMT
# INT_COLOR_CD
# INT_COLOR_CD_DESC
# INT_COLOR_DLR_PRICE_AMT
# INT_COLOR_RTL_PRICE_AMT
# OPTN_I1_CD
# OPTN_CD_I1_DESC
# OPTN_DLR_PRICE_I1_AMT
# OPTN_RTL_PRICE_I1_AMT
# OPTN_I2_CD
# OPTN_CD_I2_DESC
# OPTN_DLR_PRICE_I2_AMT
# OPTN_RTL_PRICE_I2_AMT
# OPTN_I3_CD
# OPTN_CD_I3_DESC
# OPTN_DLR_PRICE_I3_AMT
# OPTN_RTL_PRICE_I3_AMT
# OPTN_I4_CD
# OPTN_CD_I4_DESC
# OPTN_DLR_PRICE_I4_AMT
# OPTN_RTL_PRICE_I4_AMT
# OPTN_I5_CD
# OPTN_CD_I5_DESC
# OPTN_DLR_PRICE_I5_AMT
# OPTN_RTL_PRICE_I5_AMT
# OPTN_I6_CD
# OPTN_CD_I6_DESC
# OPTN_DLR_PRICE_I6_AMT
# OPTN_RTL_PRICE_I6_AMT
# OPTN_I7_CD
# OPTN_CD_I7_DESC
# OPTN_DLR_PRICE_I7_AMT
# OPTN_RTL_PRICE_I7_AMT
# OPTN_I8_CD
# OPTN_CD_I8_DESC
# OPTN_DLR_PRICE_I8_AMT
# OPTN_RTL_PRICE_I8_AMT
# OPTN_I9_CD
# OPTN_CD_I9_DESC
# OPTN_DLR_PRICE_I9_AMT
# OPTN_RTL_PRICE_I9_AMT
# OPTN_I10_CD
# OPTN_CD_I10_DESC
# OPTN_DLR_PRICE_I10_AMT
# OPTN_RTL_PRICE_I10_AMT
# OPTN_I11_CD
# OPTN_CD_I11_DESC
# OPTN_DLR_PRICE_I11_AMT
# OPTN_RTL_PRICE_I11_AMT
# OPTN_I12_CD
# OPTN_CD_I12_DESC
# OPTN_DLR_PRICE_I12_AMT
# OPTN_RTL_PRICE_I12_AMT
# OPTN_I13_CD
# OPTN_CD_I13_DESC
# OPTN_DLR_PRICE_I13_AMT
# OPTN_RTL_PRICE_I13_AMT
# OPTN_I14_CD
# OPTN_CD_I14_DESC
# OPTN_DLR_PRICE_I14_AMT
# OPTN_RTL_PRICE_I14_AMT
# OPTN_I15_CD
# OPTN_CD_I15_DESC
# OPTN_DLR_PRICE_I15_AMT
# OPTN_RTL_PRICE_I15_AMT
# OPTN_I16_CD
# OPTN_CD_I16_DESC
# OPTN_DLR_PRICE_I16_AMT
# OPTN_RTL_PRICE_I16_AMT
# OPTN_I17_CD
# OPTN_CD_I17_DESC
# OPTN_DLR_PRICE_I17_AMT
# OPTN_RTL_PRICE_I17_AMT
# OPTN_I18_CD
# OPTN_CD_I18_DESC
# OPTN_DLR_PRICE_I18_AMT
# OPTN_RTL_PRICE_I18_AMT
# OPTN_I19_CD
# OPTN_CD_I19_DESC
# OPTN_DLR_PRICE_I19_AMT
# OPTN_RTL_PRICE_I19_AMT
# OPTN_I20_CD
# OPTN_CD_I20_DESC
# OPTN_DLR_PRICE_I20_AMT
# OPTN_RTL_PRICE_I20_AMT
# EXTRA_COST_I1_TYPE
# EXTRA_COST_TYPE_I1_DESC
# EXTRA_COST_DLR_I1_AMT
# EXTRA_COST_RTL_I1_AMT
# EXTRA_COST_I2_TYPE
# EXTRA_COST_TYPE_I2_DESC
# EXTRA_COST_DLR_I2_AMT
# EXTRA_COST_RTL_I2_AMT
# EXTRA_COST_I3_TYPE
# EXTRA_COST_TYPE_I3_DESC
# EXTRA_COST_DLR_I3_AMT
# EXTRA_COST_RTL_I3_AMT
# EXTRA_COST_I4_TYPE
# EXTRA_COST_TYPE_I4_DESC
# EXTRA_COST_DLR_I4_AMT
# EXTRA_COST_RTL_I4_AMT
# EXTRA_COST_I5_TYPE
# EXTRA_COST_TYPE_I5_DESC
# EXTRA_COST_DLR_I5_AMT
# EXTRA_COST_RTL_I5_AMT
# EXTRA_COST_I6_TYPE
# EXTRA_COST_TYPE_I6_DESC
# EXTRA_COST_DLR_I6_AMT
# EXTRA_COST_RTL_I6_AMT
# EXTRA_COST_I7_TYPE
# EXTRA_COST_TYPE_I7_DESC
# EXTRA_COST_DLR_I7_AMT
# EXTRA_COST_RTL_I7_AMT
# EXTRA_COST_I8_TYPE
# EXTRA_COST_TYPE_I8_DESC
# EXTRA_COST_DLR_I8_AMT
# EXTRA_COST_RTL_I8_AMT
# EXTRA_COST_I9_TYPE
# EXTRA_COST_TYPE_I9_DESC
# EXTRA_COST_DLR_I9_AMT
# EXTRA_COST_RTL_I9_AMT
# EXTRA_COST_I10_TYPE
# EXTRA_COST_TYPE_I10_DESC
# EXTRA_COST_DLR_I10_AMT
# EXTRA_COST_RTL_I10_AMT
# TOTAL_DLR_PRICE_AMT
# RTL_PRICE_TOT_AMT
# COUNTRY_NM
# SRC_FILE_NM
# CREATE_BY_NM
# CREATE_DT
# MOD_BY_NM
# MOD_DT

# %%
for column_name in vehicle_invoice_data_md:  if column_name.contains("OPTN_CD"): print(column_name)
# Out:
#   File "<ipython-input-34-c950fbf9e89d>", line 1
#     for column_name in vehicle_invoice_data_md:  if column_name.contains("OPTN_CD"): print(column_name)
#                                                   ^
# SyntaxError: invalid syntax

# %%
vehicle_invoice_data_cd = vehicle_invoice_data_md[vehicle_invoice_data.str.contains('OPTN_CD')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-7e49605e6d65> in <module>
# ----> 1 vehicle_invoice_data_cd = vehicle_invoice_data_md[vehicle_invoice_data.str.contains('OPTN_CD')]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %% [markdown]
# Example of transpose in panda

# %%
import pandas as pd

d = {'one' : pd.Series([1., 2., 3.],     index=['a', 'b', 'c']),
    'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

# %%
print("Starting with this dataframe\n", df)
# Out:
# Starting with this dataframe
#     one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
print("The first column is a", type(df['one']), "\nconsisting of\n", df['one'])
# Out:
# The first column is a <class 'pandas.core.series.Series'>
# consisting of
#  a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
dfToList = df['one'].tolist()

dfList = list(df['one'])

dfValues = df['one'].values

print("dfToList is", dfToList, "and it's a", type(dfToList))
print("dfList is  ", dfList,   "and it's a", type(dfList))
print("dfValues is", dfValues, "and it's a", type(dfValues))
# Out:
# dfToList is [1.0, 2.0, 3.0, nan] and it's a <class 'list'>
# dfList is   [1.0, 2.0, 3.0, nan] and it's a <class 'list'>
# dfValues is [ 1.  2.  3. nan] and it's a <class 'numpy.ndarray'>
